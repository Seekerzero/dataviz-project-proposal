# %%
import pandas as pd
import os
# home = os.path.expanduser("~")
# home = home + "/Desktop/CS573/dataviz-project-proposal/"
home = "C:/Users/Seeker/Desktop/dataviz-project-proposal/"

# %%
url="https://gist.githubusercontent.com/Seekerzero/06f88ebffbbac07cdf39ddbee3da70eb/raw/b3e5f8f1a371a8b8005393c15b84a96dbaf7cffe/vaccination-data.csv"
data = pd.read_csv(url)

# %%
data.head()
# Out:
#           COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0     Afghanistan  AFG       EMRO   REPORTING   2023-01-16
# 1         Albania  ALB       EURO   REPORTING   2023-01-08
# 2         Algeria  DZA       AFRO   REPORTING   2022-09-04
# 3  American Samoa  ASM       WPRO   REPORTING   2022-08-23
# 4         Andorra  AND       EURO   REPORTING   2022-12-18
#
#    TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0          12603486.0                       11606705
# 1           3042696.0                        1344067
# 2          15267442.0                        7840131
# 3            111316.0                          44885
# 4            156242.0                          57901
#
#    TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                     32.376                                29.816
# 1                    105.700                                47.227
# 2                     34.817                                17.879
# ...

# %%
total_vaccination_with_iso = data[["ISO3", "TOTAL_VACCINATIONS"]]
total_vaccination_with_iso.head()
total_vaccination_rename = total_vaccination_with_iso.rename(columns={"ISO3":"iso", "TOTAL_VACCINATIONS": "value"})

# %%
dir = home+ "total_vaccination_with_iso.csv"
total_vaccination_rename.to_csv(dir ,index=False)

# %%
gdp_url = "https://gist.githubusercontent.com/Seekerzero/e64c49ffea90f1a52a027e057f86629c/raw/7a270c9fd9a2e191c3ffbd94b4493fe510596793/global_gdp_2023-03-01.csv"
gdp_data = pd.read_csv(gdp_url)
gdp_data
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 2                    Afghanistan          AFG  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  GDP (current US$)
# 262                  Yemen, Rep.          YEM  GDP (current US$)
# 263                 South Africa          ZAF  GDP (current US$)
# 264                       Zambia          ZMB  GDP (current US$)
# 265                     Zimbabwe          ZWE  GDP (current US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# ...

# %%
gdp_2021_with_iso = gdp_data[["Country Code", "2021"]]
gdp_2021_with_iso.head()
gdp_2021_with_iso_rename = gdp_2021_with_iso.rename(columns={"Country Code":"alpha3", "2021": "gdp"})
gdp_2021_with_iso_rename
# Out:
#     alpha3           gdp
# 0      ABW  3.126019e+09
# 1      AFE  1.089454e+12
# 2      AFG  1.478686e+10
# 3      AFW  8.401873e+11
# 4      AGO  6.740429e+10
# ..     ...           ...
# 261    XKX  9.412034e+09
# 262    YEM           NaN
# 263    ZAF  4.190150e+11
# 264    ZMB  2.214763e+10
# 265    ZWE  2.837124e+10
#
# [266 rows x 2 columns]

# %%
dir = home+"gdp_2021_with_iso.csv"
gdp_2021_with_iso_rename.to_csv(dir ,index=False)
dir
# Out:
# 'C:/Users/Seeker/Desktop/dataviz-project-proposal/gdp_2021_with_iso.csv'
